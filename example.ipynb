# %%
import energymap4py as em
res = em.by_polygon()
for i in res:
    print(i)
# Out:
# http://localhost:3000/query?mode=polygon&linestring=13.322027104721627,52.51773514881992,13.321124828370177,52.516709837521866,13.323525466163757,52.51597401976454,13.324266491874166,52.5169650913811,13.322847600680866,52.517782208350184
# ...

# %%
res = em.by_uuid('DEBE04YY500002vO')
for i in res:
    print(i)
# Out:
# http://localhost:3000/query?mode=uuid&uuid=DEBE04YY500002vO
# ...
