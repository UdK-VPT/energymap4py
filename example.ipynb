# %%
from energymap4py import data_access as em_data
res = em_data.by_polygon()
for i in res:
    print(i)

# %%
from energymap4py import ai_model as em_model
em_model.predict('DEBE04YY500002vO', domestic_hot_water_demand=13.333)
# Out:
# https://energymap-berlin.de/model/nn?uuid=DEBE04YY500002vO&bldg_type=GMH&plant_eff=0.93&hwd=13.333
# [{'uuid': 'DEBE04YY500002vO',
#   'heat_demand': 1297914.663372523,
#   'specific_heat_demand': 61.464478648096176,
#   'co2_emission': 223241322.10007393,
#   'ee_class': 'B'}]

# %%
res = em_data.by_uuid('DEBE04YY500002vO')
for i in res:
    print(i)

# %%
res = em_data.by_line(dist=100)
for i in res:
    print(i)

# %%
res = em_data.by_point(dist=100)
for i in res:
    print(i)
