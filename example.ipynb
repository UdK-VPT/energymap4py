# %%
import energymap4py as em
res = em.by_polygon()
for i in res:
    print(i)
# Out:
# https://energymap-berlin.de/map/query?mode=polygon&linestring=13.322027104721627,52.51773514881992,13.321124828370177,52.516709837521866,13.323525466163757,52.51597401976454,13.324266491874166,52.5169650913811,13.322847600680866,52.517782208350184
# ...

# %%
res = em.by_uuid('DEBE04YY500002vO')
for i in res:
    print(i)
# Out:
# https://energymap-berlin.de/map/query?mode=uuid&uuid=DEBE04YY500002vO
# ...

# %%
res = em.by_line(dist=100)
for i in res:
    print(i)
# Out:
# https://energymap-berlin.de/map/query?mode=line&linestring=13.324412829321979,52.516957033745285,13.322429034685205,52.514576803927426,13.322485599381766,52.51321707446597&distance=100
# ...

# %%
res = em.by_point(dist=100)
for i in res:
    print(i)
# Out:
# https://energymap-berlin.de/map/query?mode=point&longitude=13.467488494175514&latitude=52.50587905804428&distance=100
# ...
