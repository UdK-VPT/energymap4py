# %%
import energymap4py as em
res = em.by_polygon()
for i in res:
    print(i)
# Out:
# http://localhost:3000/bldgbypolygon/13.322027104721627&52.51773514881992&13.321124828370177&52.516709837521866&13.323525466163757&52.51597401976454&13.324266491874166&52.5169650913811&13.322847600680866&52.517782208350184
# ...

# %%
res = em.by_uuid('DEBE04YY500002vO')
for i in res:
    print(i)
# Out:
# http://localhost:3000/bldg/DEBE04YY500002vO
# {'fid': '134694', 'uuid': 'DEBE04YY500002vO', 'geom': '...', 'displayed': True, 'gfk': 3023, 'bezgfk': 'Hochschulgebäude (Fachhochschule, Universität)', 'ofl': 1400, 'bezofl': 'Aufgeständert', 'aog': 6, 'aug': None, 'hoh': None, 'bat': None, 'bezbat': None, 'nam': 'Universität der Künste Fakultät für Gestaltung und Bildende Kunst', 'baw': None, 'bezbaw': None, 'zus': None, 'bezzus': None, 'lag': '01102', 'namlag': 'Einsteinufer 43', 'hnr': '43', 'pnr': None, 'lnr': None, 'bezeich': 'AX_Gebaeude', 'mostly_in_pca': '10587', 'mostly_in_block': '22089', 'mostly_in_plot': '11000700600355', 'heritage_id': '09040478', 'heritage_type': 'Baudenkmal', 'height': None, 'roof_type': None, 'roof_description': None, 'heated': True, 'usage_type': 'NWG', 'building_type': 'TG', 'ground_area': '4449.27', 'nrf_area': '21356.47', 'rand_spec_cons': '104.00', 'std': '0.5535', 'cons': '2221073', 'efficiency_class': 'D'}
