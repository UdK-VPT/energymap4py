# %%
# If neccesary install once:
# !pip install ipyleaflet ipywidgets
from ipyleaflet import Map, TileLayer, DrawControl
from ipywidgets import HTML, VBox
from energymap4py import data_access as em_data

# %% [markdown]
# # EnergyMap data from a OSM map
# ## This example shows how multiple buildings can be selected interactively on an OSM map using a polyline or polygon tool, for which information can then be retrieved from the EnergyMap database.

# %%
# Helping functions for catching coordinates of selected polylines or polygons from OSM 
def _store_line_from_geojson(geo_json, source="callback"):
    global poly_coords_ll, poly_geojson, polygon_coords_ll, polygon_geojson, info
    if not geo_json:
        return
    geom = geo_json.get("geometry", {})
    if geom.get("type") == "LineString":
        poly_geojson = geo_json
        poly_coords_ll = geom["coordinates"]  # GeoJSON-order: [lon, lat]
        info.value = f"<b>Polyline defined:</b> ({len(poly_coords_ll)} Points, {source})"
    if geom.get("type") == "Polygon":
        # GeoJSON-Polygone: List of rings -> [exterior, hole1, hole2, ...]
        rings = geom.get("coordinates", [])
        if rings:
            polygon_coords_ll = rings[0] # outer ring (lon, lat)
            polygon_geojson = geo_json
            info.value = f"<b>Polygon defined:</b> ({len(polygon_coords_ll)} Points, {source})."
        else:
            info.value = "Got empty polygon."
    else:
        info.value = HTML("Please draw a <b>Polyline</b> or a <b>Polygon</b>. Click, for defining coordinates – <b>double click</b> finishing polyline or close polygon.")

# 1) Compatible on_draw: catches (action, geo_json) AND (target, action, geo_json)
def on_draw(*args, **kwargs):
    if len(args) == 2:
        action, geo_json = args
    elif len(args) == 3:
        _, action, geo_json = args
    else:
        action = kwargs.get("action")
        geo_json = kwargs.get("geo_json")
    _store_line_from_geojson(geo_json, source="on_draw")

# 2) Fallback/Sync: observing feature-collection-state
def _sync_from_data(change):
    fc = change["new"]
    if not fc or not fc.get("features"):
        return
    last = fc["features"][-1]
    _store_line_from_geojson(last, source="observe")

# %% [markdown]
# ## OSM Map Setup

# %%
poly_coords_ll = []   # coordinate list of the polyline: [[lon, lat], ...]
poly_geojson = None   # GeoJSON feature (LineString)

polygon_coords_ll = []  # coordinate list of the polygon: [[lon, lat], ...]
polygon_geojson = None  # GeoJSON feature (Polygon)

m = Map(center=(52.532461318193775,13.422214655200957), zoom=17, scroll_wheel_zoom=True)
m.add_layer(TileLayer(url="https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png", name="OSM"))
draw = DrawControl(polyline={"shapeOptions": {"weight": 4}}, polygon={"shapeOptions": {"weight": 4}})
# deactivate tools by empty dicts !
#draw.polygon = {}
#draw.polyline = {}
draw.circle = {}
draw.rectangle = {}
draw.marker = {}
draw.circlemarker = {}

draw.on_draw(on_draw)
draw.observe(_sync_from_data, names="data")
m.add_control(draw)

info = HTML("Please draw a <b>Polyline</b> or a <b>Polygon</b>. Click, for defining coordinates – <b>double click</b> finishing polyline or close polygon.")
VBox([m, info])

# %%
# List of coordinates
print(poly_coords_ll, polygon_coords_ll)
# Out:
# [[13.416434, 52.532274], [13.417153, 52.532751], [13.418161, 52.532437]] [[13.424033, 52.532596], [13.425664, 52.534358], [13.429355, 52.533092], [13.427252, 52.531473], [13.424033, 52.532596]]

# %% [markdown]
# ## Information about all buildings from the EnergyMap database 20 m left and right of the polyline

# %%
coords = []
for i in range(len(poly_coords_ll)):
    coords.append((poly_coords_ll[i][0],poly_coords_ll[i][1]))
print(coords)
# information 
res = em_data.by_line(line_points=coords, dist=20)
for r in res:
    print('uuid:',r['uuid'],'street:',r['street_name'],'age:',r['year_of_construction'],'heat present:',r['cons_c1r1'],'[kWh/a]','spec. heat present:',r['spec_cons_c1r1'],'[kWh/m2a]')
# Out:
# [(13.416434, 52.532274), (13.417153, 52.532751), (13.418161, 52.532437)]
# https://energymap-berlin.de/map/query?mode=line&linestring=13.416434,52.532274,13.417153,52.532751,13.418161,52.532437&distance=20
# uuid: DEBE03YY600005aV street: Belforter Straße 11 age: 1976 heat present: 247777.83 [kWh/a] spec. heat present: 132.96 [kWh/m2a]
# uuid: DEBE00YY1Kb000AL street: Belforter Straße 8 age: 1953 heat present: 199304.38 [kWh/a] spec. heat present: 91.23 [kWh/m2a]
# uuid: DEBE00YY1Kb000Be street: Straßburger Straße 32 age: 1953 heat present: 191977.03 [kWh/a] spec. heat present: 86.63 [kWh/m2a]
# uuid: DEBE03YY6000053f street: Straßburger Straße 27 age: 1879 heat present: 140191.06 [kWh/a] spec. heat present: 109.94 [kWh/m2a]
# uuid: DEBE03YY6000045I street: Belforter Straße 9 age: 1879 heat present: 109181.30 [kWh/a] spec. heat present: 106.35 [kWh/m2a]
# uuid: DEBE03YY600005jY street: Straßburger Straße 29 age: 1879 heat present: 114517.45 [kWh/a] spec. heat present: 104.79 [kWh/m2a]
# uuid: DEBE03YY60000BtH street: Straßburger Straße 26 age: 1879 heat present: 88173.66 [kWh/a] spec. heat present: 141.86 [kWh/m2a]
# uuid: DEBE03YY600003cp street: Belforter Straße 10 age: 1879 heat present: 160603.41 [kWh/a] spec. heat present: 154.97 [kWh/m2a]
# uuid: DEBE03YY600001Ge street: Belforter Straße 25 age: 1879 heat present: 168254.67 [kWh/a] spec. heat present: 139.05 [kWh/m2a]
# uuid: DEBE03YY60000Cyv street: Straßburger Straße 28 age: 1879 heat present: 112697.92 [kWh/a] spec. heat present: 113.80 [kWh/m2a]
# uuid: DEBE03YY6000060a street: Belforter Straße 26; Kolmarer Straße 1 age: 1879 heat present: 202032.07 [kWh/a] spec. heat present: 136.46 [kWh/m2a]
# uuid: DEBE00YY1Kb000Au street: Straßburger Straße 31 age: 2005 heat present: 154372.78 [kWh/a] spec. heat present: 57.19 [kWh/m2a]
# uuid: DEBE00YY1Kb000CM street: Straßburger Straße 33 age: 2005 heat present: 207322.41 [kWh/a] spec. heat present: 60.25 [kWh/m2a]

# %% [markdown]
# ## Information about all buildings from the EnergyMap database which are completely located within the polygon

# %%
#coords = [(13.322027104721627, 52.51773514881992),(13.321124828370177, 52.516709837521866),(13.323525466163757, 52.51597401976454),(13.324266491874166, 52.5169650913811),(13.322847600680866, 52.517782208350184)]
coords = []
for i in range(len(polygon_coords_ll)):
    coords.append((polygon_coords_ll[i][0],polygon_coords_ll[i][1]))
print(coords)
res = em_data.by_polygon(polygon_points=coords)
for r in res:
    print('uuid:',r['uuid'],'street:',r['street_name'],'age:',r['year_of_construction'],'heat present:',r['cons_c1r1'],'[kWh/a]','spec. heat present:',r['spec_cons_c1r1'],'[kWh/m2a]')
# Out:
# [(13.424033, 52.532596), (13.425664, 52.534358), (13.429355, 52.533092), (13.427252, 52.531473), (13.424033, 52.532596)]
# https://energymap-berlin.de/map/query?mode=polygon&linestring=13.424033,52.532596,13.425664,52.534358,13.429355,52.533092,13.427252,52.531473,13.424033,52.532596
# uuid: DEBE03YY600008Kn street: Marienburger Straße age: 1879 heat present: 19715.36 [kWh/a] spec. heat present: 164.18 [kWh/m2a]
# uuid: DEBE03AL59X0000H street: Immanuelkirchstraße age: 1879 heat present: 64208.22 [kWh/a] spec. heat present: 168.66 [kWh/m2a]
# uuid: DEBE03YY600001v1 street: Marienburger Straße age: 1900 heat present: 106992.18 [kWh/a] spec. heat present: 214.29 [kWh/m2a]
# uuid: DEBE03YY600001yw street: Marienburger Straße age: 1925 heat present: 22098.52 [kWh/a] spec. heat present: 185.65 [kWh/m2a]
# uuid: DEBE03YY600003Rz street: Marienburger Straße age: 1879 heat present: 38546.60 [kWh/a] spec. heat present: 242.44 [kWh/m2a]
# uuid: DEBE03YY600004ji street: Greifswalder Straße age: 1909 heat present: 67958.68 [kWh/a] spec. heat present: 184.01 [kWh/m2a]
# uuid: DEBE03YY60000Abc street: Immanuelkirchstraße age: 1879 heat present: 50636.99 [kWh/a] spec. heat present: 194.58 [kWh/m2a]
# uuid: DEBE03YY600005XB street: Greifswalder Straße age: 1900 heat present: 53347.23 [kWh/a] spec. heat present: 159.87 [kWh/m2a]
# uuid: DEBE03YY600004Ue street: Marienburger Straße age: 1900 heat present: 78716.43 [kWh/a] spec. heat present: 177.88 [kWh/m2a]
# uuid: DEBE03YY60000BaF street: Greifswalder Straße age: 1909 heat present: 286440.61 [kWh/a] spec. heat present: 141.30 [kWh/m2a]
# uuid: DEBE03YY60000B2r street: Winsstraße age: 1909 heat present: 118183.18 [kWh/a] spec. heat present: 183.77 [kWh/m2a]
# uuid: DEBE03YY60000BHa street: Greifswalder Straße age: 1909 heat present: 71583.92 [kWh/a] spec. heat present: 208.23 [kWh/m2a]
# uuid: DEBE03YY60000Apm street: Greifswalder Straße 212, 213 age: 1976 heat present: 523701.09 [kWh/a] spec. heat present: 131.34 [kWh/m2a]
# uuid: DEBE03YY60000A8w street: Marienburger Straße 23 age: 1879 heat present: 101819.27 [kWh/a] spec. heat present: 122.41 [kWh/m2a]
# uuid: DEBE03YY600003nH street: Greifswalder Straße 215; Immanuelkirchstraße 18 age: 1879 heat present: 44183.49 [kWh/a] spec. heat present: 215.67 [kWh/m2a]
# uuid: DEBE03YY600008P2 street: Immanuelkirchstraße 23 age: 1909 heat present: 287012.56 [kWh/a] spec. heat present: 138.58 [kWh/m2a]
# uuid: DEBE03YY600005kv street: Greifswalder Straße age: 1879 heat present: 76005.20 [kWh/a] spec. heat present: 134.02 [kWh/m2a]
# uuid: DEBE03YY60000Dim street: Marienburger Straße 22 age: 1879 heat present: 116624.54 [kWh/a] spec. heat present: 141.01 [kWh/m2a]
# uuid: DEBE03YY6000061q street: Greifswalder Straße 206 age: 1909 heat present: 193438.84 [kWh/a] spec. heat present: 146.24 [kWh/m2a]
# uuid: DEBE03YY60000A9V street: Winsstraße 17 age: 1909 heat present: 370520.96 [kWh/a] spec. heat present: 156.41 [kWh/m2a]
# uuid: DEBE03YY60000504 street: Immanuelkirchstraße 24 age: 1879 heat present: 283571.98 [kWh/a] spec. heat present: 134.51 [kWh/m2a]
# uuid: DEBE03YY60000Cwf street: Immanuelkirchstraße 26 age: 1879 heat present: 286080.24 [kWh/a] spec. heat present: 130.44 [kWh/m2a]
# uuid: DEBE03YY60000B42 street: Greifswalder Straße 214 age: 1879 heat present: 204068.10 [kWh/a] spec. heat present: 137.83 [kWh/m2a]
# uuid: DEBE03YY60000Chn street: Winsstraße 13 age: 1909 heat present: 240228.97 [kWh/a] spec. heat present: 128.69 [kWh/m2a]
# uuid: DEBE03YY60000Bey street: Winsstraße 12 age: 1909 heat present: 148997.16 [kWh/a] spec. heat present: 117.90 [kWh/m2a]
# uuid: DEBE03YY60000AWW street: Greifswalder Straße age: 1879 heat present: 168367.90 [kWh/a] spec. heat present: 133.21 [kWh/m2a]
# uuid: DEBE03YY60000B2h street: Immanuelkirchstraße 21 age: 1909 heat present: 292242.46 [kWh/a] spec. heat present: 118.62 [kWh/m2a]
# uuid: DEBE03YY60000D4x street: Marienburger Straße age: 1879 heat present: 126759.43 [kWh/a] spec. heat present: 155.25 [kWh/m2a]
# uuid: DEBE03YY60000DBv street: Greifswalder Straße 210 age: 1879 heat present: 78878.56 [kWh/a] spec. heat present: 128.15 [kWh/m2a]
# uuid: DEBE03YY6000086u street: Greifswalder Straße age: 1879 heat present: 74911.57 [kWh/a] spec. heat present: 136.33 [kWh/m2a]
# uuid: DEBE03YY600008rV street: Immanuelkirchstraße 27 age: 1879 heat present: 306130.09 [kWh/a] spec. heat present: 141.38 [kWh/m2a]
# uuid: DEBE03YY6000092v street: Marienburger Straße age: 1879 heat present: 0.00 [kWh/a] spec. heat present: 0.00 [kWh/m2a]
